# %% [markdown]
# ## Laptop Price Prediction

# %%
import pandas as pd

# %%
df=pd.read_csv('laptop_dataa.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
#1303 rows and 12 columns
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
#how many duplicated rows are in the data
# Out:
# 0

# %%
df.describe()
#only works for the numerical values
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB',"")
df['Weight']=df['Weight'].str.replace('kg',"")

# %%
df.sample(5)
#when you use df.sample, it gives you random rows as the output
# Out:
#       Company  TypeName  Inches             ScreenResolution  \
# 143   Toshiba  Notebook    15.6                     1366x768
# 686        HP  Notebook    15.6                     1366x768
# 57       Asus  Notebook    15.6                     1366x768
# 718  Mediacom  Notebook    14.0  IPS Panel Full HD 1920x1200
# 500      Asus   Netbook    11.6                     1366x768
#
#                                       Cpu Ram              Memory  \
# 143            Intel Core i5 6200U 2.3GHz   4           500GB HDD
# 686            Intel Core i5 7200U 2.5GHz   4           500GB HDD
# 57             Intel Core i5 7200U 2.5GHz   4           256GB SSD
# 718              Intel Atom Z8350 1.92GHz   4            32GB HDD
# 500  Intel Celeron Dual Core N3350 1.1GHz   4  64GB Flash Storage
#
#                        Gpu         OpSys Weight       Price
# 143  Intel HD Graphics 520    Windows 10    2.1  32074.5600
# 686         AMD Radeon 520    Windows 10   1.86  32639.8608
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')
#changes the type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
#this code above shows the text overlapping, the code ensures this doesn't happen
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
#this code above shows the text overlapping, the code ensures this doesn't happen
plt.show()

# %%
sns.distplot(df['Inches'])
plt.show()
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/3809510925.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)
#creates a custom column from the data, where if the laptop is touchscreen, show 1 else show 0

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 1071      HP  Notebook    15.6                     1366x768
# 586       HP    Gaming    17.3  IPS Panel Full HD 1920x1080
# 745     Acer  Notebook    14.0                     1366x768
# 162     Dell  Notebook    15.6            Full HD 1920x1080
# 498   Lenovo  Notebook    13.3  IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1071            Intel Core i5 6200U 2.3GHz    4             500GB HDD
# 586            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 745   Intel Celeron Dual Core N3060 1.6GHz    2    32GB Flash Storage
# 162             Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 498             Intel Core i3 7100U 2.4GHz    8             256GB SSD
#
#                           Gpu       OpSys  Weight     Price  Touchscreen
# 1071    Intel HD Graphics 520  Windows 10    2.31  63882.72            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='pie',autopct='%.1f%%')
#shows a pie chart for the laptops that have a touchscreen and laptops that don't
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df['Touchscreen'],y=df['Price'])
#figsize changes the size of the barplot based on what you want
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
#screen resolution has 2 types. If there is 'IPS' in the screen resolution, it will mark as 1

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts()
# Out:
# Ips
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.corr(numeric_only=True)
#correlation chart that shows which factors impact which
# Out:
#                Inches       Ram    Weight     Price  Touchscreen       Ips
# Inches       1.000000  0.237993  0.827631  0.068197    -0.361735 -0.114804
# Ram          0.237993  1.000000  0.383874  0.743007     0.116984  0.206623
# Weight       0.827631  0.383874  1.000000  0.210370    -0.294620  0.016967
# Price        0.068197  0.743007  0.210370  1.000000     0.191226  0.252208
# Touchscreen -0.361735  0.116984 -0.294620  0.191226     1.000000  0.150512
# Ips         -0.114804  0.206623  0.016967  0.252208     0.150512  1.000000

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res']=df['X_res'].str.replace(",","").str.findall(r'(\d+.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
#Calculating PPI(Pixels per inches)sqrt(X_res+Y_res/Inches)
df['PPI'] = (((df['X_res']**2)+(df['Y_res']))**0.5/df['Inches']).astype('float')

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.474960
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Y_res','X_res','Inches'],inplace=True)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample()
# Out:
#     Company  TypeName                         Cpu  Ram     Memory  \
# 899    Dell  Notebook  Intel Core i5 7300U 2.6GHz    8  500GB HDD
#
#                        Gpu       OpSys  Weight    Price  Touchscreen  Ips  \
# 899  Intel HD Graphics 620  Windows 10     1.9  49816.8            0    0
#
#             PPI       Cpu Name
# 899  123.094951  Intel Core i5

# %%
def fetch_processor(text):
    if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
        return text
    else:
        if text.split()[0] == 'Intel':
            return "Other Intel Processor"
        else:
            return "AMD Processor"

# %%
df["Cpu brand"]=df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(10)
# Out:
#      Company   TypeName                          Cpu  Ram  \
# 734   Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    8
# 197       HP   Notebook   Intel Core i5 8250U 1.6GHz    8
# 1051      HP   Notebook   Intel Core i7 7500U 2.7GHz    8
# 60      Dell   Notebook   Intel Core i7 8550U 1.8GHz   16
# 425     Dell     Gaming  Intel Core i7 7700HQ 2.8GHz    8
# 506     Asus   Notebook   Intel Core i7 7500U 2.7GHz    8
# 56        HP   Notebook     Intel Core i3 6006U 2GHz    4
# 761     Dell  Ultrabook   Intel Core i7 7600U 2.8GHz   16
# 543     Acer     Gaming  Intel Core i5 7300HQ 2.5GHz    8
# 72      Dell   Notebook   Intel Core i7 8550U 1.8GHz    8
#
#                     Memory                         Gpu       OpSys  Weight  \
# 734              256GB SSD       Intel HD Graphics 620  Windows 10    1.44
# 197              512GB SSD      Intel UHD Graphics 620  Windows 10    1.49
# 1051               1TB HDD        Nvidia GeForce 940MX  Windows 10    1.91
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation=60)
#tilts the name on the x axis by 60 degrees
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.sample(5)
# Out:
#       Company  TypeName  Ram                Memory                      Gpu  \
# 952   Toshiba  Notebook    8             256GB SSD    Intel HD Graphics 520
# 522      Dell  Notebook    8             256GB SSD    Intel HD Graphics 620
# 1211     Asus  Notebook   16  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060
# 339      Dell  Notebook    8             256GB SSD     Nvidia GeForce 940MX
# 625    Lenovo  Notebook    8               1TB HDD     Nvidia GeForce 920MX
#
#            OpSys  Weight       Price  Touchscreen  Ips         PPI  \
# 952    Windows 7    1.20  77788.8000            0    0  144.382047
# 522   Windows 10    1.64  68184.0144            0    0  137.162945
# 1211  Windows 10    2.20  93186.7200            0    0  123.094951
# 339   Windows 10    2.00  60885.7200            0    0  123.094951
# 625   Windows 10    2.20  47898.7200            0    0  123.094951
#
#           Cpu brand
# 952   Intel Core i5
# 522   Intel Core i5
# 1211  Intel Core i7
# ...

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True) #remove 0.0 from string
df['Memory']=df['Memory'].str.replace('GB','') 
df['Memory']=df['Memory'].str.replace('TB','000')
new=df['Memory'].str.split("+",n=1,expand=True) #split string on +

# %%
df.sample(5)
# Out:
#      Company     TypeName  Ram    Memory                    Gpu       OpSys  \
# 547   Lenovo     Notebook    4  1000 HDD  Intel HD Graphics 520       No OS
# 749       HP  Workstation   16   256 SSD   Nvidia Quadro M2000M   Windows 7
# 1302    Asus     Notebook    4   500 HDD      Intel HD Graphics  Windows 10
# 1181  Lenovo    Ultrabook    6   256 SSD    Nvidia GeForce 920M  Windows 10
# 309       HP     Notebook    4  1000 HDD  Intel HD Graphics 520  Windows 10
#
#       Weight       Price  Touchscreen  Ips         PPI              Cpu brand
# 547     2.15   24634.008            0    0  123.094951          Intel Core i5
# 749     3.00  233845.920            0    1  110.998915  Other Intel Processor
# 1302    2.20   19660.320            0    0   87.582121  Other Intel Processor
# 1181    1.54   44275.680            0    0  123.094951          Intel Core i7
# 309     1.86   24988.320            0    0  123.094951          Intel Core i3

# %%
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
df['first']=new[0]
df['first']=df['first'].str.strip()#used to remove the white spaces between a string
df['second']=new[1]

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
df["Layer1HDD"]=df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"]=df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"]=df["first"].apply(lambda x: 1 if "Hyprid" in x else 0)
df["Layer1Flash_Storage"]=df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
df["second"].fillna("0", inplace = True)

# %%
df.sample(5)
# Out:
#        Company   TypeName  Ram             Memory  \
# 457  Microsoft  Ultrabook    4            128 SSD
# 794      Apple  Ultrabook    8  512 Flash Storage
# 931         HP  Ultrabook    4            500 HDD
# 464     Lenovo   Notebook    8            256 SSD
# 458  Microsoft  Ultrabook    8            256 SSD
#
#                               Gpu         OpSys  Weight      Price  \
# 457         Intel HD Graphics 615  Windows 10 S   1.252   52693.92
# 794        Intel HD Graphics 5300      Mac OS X   0.920   62071.20
# 931         Intel HD Graphics 520    Windows 10   1.260   84129.12
# 464          Nvidia Quadro M2200M    Windows 10   2.670  111355.20
# 458  Intel Iris Plus Graphics 640  Windows 10 S   1.250   95850.72
#
#      Touchscreen  Ips         PPI              Cpu brand first second  \
# 457            1    0  167.135801  Other Intel Processor   128      0
# 794            0    1  192.026040  Other Intel Processor   512      0
# ...

# %%
df["Layer2HDD"]=df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"]=df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"]=df["second"].apply(lambda x: 1 if "Hyprid" in x else 0)
df["Layer2Flash_Storage"]=df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
df['second'] = df['second'].str.replace(r'\D', '', regex=True)
df["first"]=df["first"].astype(int)
df['second']=df['second'].astype(int)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram    Memory                    Gpu       OpSys  \
# 1130      HP   Notebook    8  2000 HDD  Intel HD Graphics 620  Windows 10
# 1127      HP  Ultrabook    8   256 SSD  Intel HD Graphics 520   Windows 7
# 100       HP   Notebook    8   256 SSD         AMD Radeon 530  Windows 10
# 1250    Dell   Notebook    4   500 HDD      Intel HD Graphics       Linux
# 11        HP   Notebook    4   500 HDD  Intel HD Graphics 520       No OS
#
#       Weight        Price  Touchscreen  Ips  ...  first second  Layer1HDD  \
# 1130    2.04   33513.1200            0    0  ...   2000      0          1
# 1127    1.26  100965.6000            0    0  ...    256      0          0
# 100     1.91   38308.3200            0    0  ...    256      0          0
# 1250    2.20   17262.7200            0    0  ...    500      0          1
# 11      1.86   18381.0672            0    0  ...    500      0          1
#
#       Layer1SSD  Layer1Hybrid  Layer1Flash_Storage  Layer2HDD  Layer2SSD  \
# ...

# %%
df["HDD"]=(df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD'])
df["SSD"]=(df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD'])
df["Hybrid"]=(df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid'])
df["Flash_Storage"]=(df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage'])

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram   Memory                     Gpu  \
# 833   Lenovo            Notebook    8  256 SSD   Intel HD Graphics 520
# 199       HP            Notebook    8  256 SSD   Nvidia GeForce 930MX
# 470       HP  2 in 1 Convertible    8  512 SSD  Intel UHD Graphics 620
# 1111    Dell            Notebook    4  500 HDD      AMD Radeon R5 M315
# 924   Lenovo  2 in 1 Convertible    8  512 SSD   Intel HD Graphics 620
#
#            OpSys  Weight       Price  Touchscreen  Ips  ...  Layer1Hybrid  \
# 833   Windows 10    1.70   63190.080            0    0  ...             0
# 199   Windows 10    2.50   55677.600            0    0  ...             0
# 470   Windows 10    1.29  106506.720            1    1  ...             0
# 1111   Windows 7    2.24   40980.312            0    0  ...             0
# 924   Windows 10    1.37   97236.000            1    1  ...             0
#
#      Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 779     Asus            Notebook    8              128 SSD
# 524     Dell            Notebook    8  128 SSD +  1000 HDD
# 1275    Asus           Ultrabook    8              512 SSD
# 343   Lenovo  2 in 1 Convertible   16              512 SSD
# 775     Asus  2 in 1 Convertible   12             2000 HDD
#
#                          Gpu       OpSys  Weight       Price  Touchscreen  \
# 779    Intel HD Graphics 505  Windows 10     2.0   31003.632            0
# 524           AMD Radeon 530       Linux     2.8   47365.920            0
# 1275   Intel HD Graphics 515  Windows 10     1.2   38841.120            0
# 343   Intel UHD Graphics 620  Windows 10     1.4  111834.720            1
# 775     Nvidia GeForce 940MX  Windows 10     2.3   44701.920            1
#
#       Ips  ...  Layer1Hybrid Layer1Flash_Storage  Layer2HDD  Layer2SSD  \
# 779     0  ...             0                   0          0          0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample(5)
# Out:
#       Company   TypeName  Ram                      Gpu       OpSys  Weight  \
# 1071       HP   Notebook    4    Intel HD Graphics 520  Windows 10    2.31
# 355      Dell   Notebook    8           AMD Radeon 530  Windows 10    2.02
# 730      Acer     Gaming   16  Nvidia GeForce GTX 1060  Windows 10    4.20
# 1120     Vero   Notebook    4    Intel HD Graphics 400  Windows 10    1.35
# 874   Samsung  Ultrabook   16     Nvidia GeForce 940MX  Windows 10    1.23
#
#            Price  Touchscreen  Ips         PPI  ... Layer1Hybrid  \
# 1071   63882.720            0    0   87.582121  ...            0
# 355    51729.552            0    0  123.094951  ...            0
# 730   103096.800            0    1  110.998915  ...            0
# 1120   10442.880            0    0  144.382047  ...            0
# 874    98514.720            0    0  128.018749  ...            0
#
#       Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df.drop(columns=['Flash_Storage','Hybrid'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 370     Asus  2 in 1 Convertible   12  Nvidia GeForce GT 940MX  Windows 10
# 1120    Vero            Notebook    4    Intel HD Graphics 400  Windows 10
# 431   Lenovo            Notebook    8    Intel HD Graphics 620  Windows 10
# 723     Dell              Gaming   32  Nvidia GeForce GTX 1070  Windows 10
# 42      Asus            Notebook    8     Nvidia GeForce 940MX       Linux
#
#       Weight        Price  Touchscreen  Ips         PPI  ... Layer1HDD  \
# 370     2.26   58554.7200            1    0  123.094951  ...         0
# 1120    1.35   10442.8800            0    0  144.382047  ...         0
# 431     1.40   53812.8000            0    1  144.382047  ...         0
# 723     4.36  194972.8320            0    0  221.981575  ...         0
# 42      2.30   27864.9072            0    0   87.582121  ...         1
#
#       Layer1SSD  Layer1Hybrid  Layer1Flash_Storage  Layer2HDD  Layer2SSD  \
# ...

# %%
df['Gpu brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['Gpu brand']!= 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'])
plt.xticks(rotation=60)
plt.show()

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/1625865374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  HDD  SSD Gpu brand
# 0  192.504698  Intel Core i5    0  128     Intel
# 1  108.294170  Intel Core i5    0    0     Intel
# 2  123.094951  Intel Core i5    0  256     Intel
# 3  187.033278  Intel Core i7    0  512       AMD
# 4  192.504698  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return "Mac"
    elif inp=='Android':
        return "Android"
    else:
        return 'No OS/Linux'

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378.6832
# 1      Apple           Ultrabook    8       macOS    1.34   47895.5232
# 2         HP            Notebook    8       No OS    1.86   30636.0000
# 3      Apple           Ultrabook   16       macOS    1.83  135195.3360
# 4      Apple           Ultrabook    8       macOS    1.37   96095.8080
# ...      ...                 ...  ...         ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866.7200
# 1300  Lenovo            Notebook    2  Windows 10    1.50   12201.1200
# 1301      HP            Notebook    6  Windows 10    2.19   40705.9200
# 1302    Asus            Notebook    4  Windows 10    2.20   19660.3200
#
#       Touchscreen  Ips         PPI              Cpu brand   HDD  SSD Gpu brand
# ...

# %%
df['os']=df['OpSys'].apply(cat_os)
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/3255695950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os']=df['OpSys'].apply(cat_os)

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378.6832
# 1      Apple           Ultrabook    8       macOS    1.34   47895.5232
# 2         HP            Notebook    8       No OS    1.86   30636.0000
# 3      Apple           Ultrabook   16       macOS    1.83  135195.3360
# 4      Apple           Ultrabook    8       macOS    1.37   96095.8080
# ...      ...                 ...  ...         ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866.7200
# 1300  Lenovo            Notebook    2  Windows 10    1.50   12201.1200
# 1301      HP            Notebook    6  Windows 10    2.19   40705.9200
# 1302    Asus            Notebook    4  Windows 10    2.20   19660.3200
#
#       Touchscreen  Ips         PPI              Cpu brand   HDD  SSD  \
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
#annot adds numerical values to the correlation
# Out:
# <Axes: >

# %%
import numpy as np

# %%
sns.distplot(np.log(df['Price']))
#np.log ensures the data is centered with equal standard deviation, without changing the data
# Out:
# /var/folders/8t/svhvtr6d5px3f6l1jt1j07d40000gn/T/ipykernel_2964/686482727.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  192.504698
# 1      Apple           Ultrabook    8    1.34            0    0  108.294170
# 2         HP            Notebook    8    1.86            0    0  123.094951
# 3      Apple           Ultrabook   16    1.83            0    1  187.033278
# 4      Apple           Ultrabook    8    1.37            0    1  192.504698
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  137.162945
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  240.622649
# 1300  Lenovo            Notebook    2    1.50            0    0   97.591506
# 1301      HP            Notebook    6    2.19            0    0   87.582121
# 1302    Asus            Notebook    4    2.20            0    0   87.582121
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
#sklearn is a website for machine learning concepts or models

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         PPI  \
# 147     Asus            Notebook    4    2.00            0    0  123.094951
# 342       HP            Notebook    8    2.10            0    1  123.094951
# 1003      HP            Notebook    4    1.64            0    0   97.591506
# 814     Dell            Notebook    8    2.18            0    0  123.094951
# 344     Dell           Ultrabook    8    1.20            0    0  144.382047
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1095    Acer            Notebook    8    2.40            0    0  123.094951
# 1130      HP            Notebook    8    2.04            0    0   87.582121
# 1295    Dell            Notebook    8    2.30            0    0   87.582121
# 860   Lenovo            Notebook    8    2.30            0    1  123.094951
# 1126  Lenovo  2 in 1 Convertible    4    0.69            1    1  190.129948
#
# ...

# %%
x_test.shape
# Out:
# (261, 12)

# %%
y_train.shape
# Out:
# (1041,)

# %%
y_test.shape
# Out:
# (261,)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le.fit_transform(df['Cpu brand'])
# Out:
# array([2, 2, 2, ..., 4, 3, 4])

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2=RandomForestRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8636227374282799
# MAE 0.17564387138341842
# /Users/anyajhalaria/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# %pwd
# Out:
# '/Users/anyajhalaria'
